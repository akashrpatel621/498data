# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# question 1
import os
nlikes = 0
tweets = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        name = (os.path.join(dirname, filename))
#         # 4 columns in dataset: C1, C2, C3, C4.
        df = pd.read_csv(name)
        tweets += len(df)

        nlikes += (df['nlikes'].sum())
# question 1
print((nlikes/tweets))

        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# question 2
import os
nlikes = 0
nretweets = 0
tweets = 0
nreplies = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        name = (os.path.join(dirname, filename))
        df = pd.read_csv(name)
        tweets += len(df)
        nretweets += df['nretweets'].sum()
        nlikes += (df['nlikes'].sum())
        nreplies += df['nreplies'].sum()

#question 2        
print(((nlikes + nretweets + nreplies)  / tweets)/0.05)

# %%
# question 3
import os
import numpy as np # linear algebra
import pandas as pd # data p

nlikes = 0
nretweets = 0
tweets = 0
nreplies = 0
tweetsize = 0

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        name = (os.path.join(dirname, filename))
        df = pd.read_csv(name)
        tweets += len(df)
        tweetsize += (len(df[df['video'] == 1])) * 4000000
        tweetsize += (len(df[df["photos"] != '[]'])) * 400000
        
        nretweets += df['nretweets'].sum()
        nlikes += (df['nlikes'].sum())
        nreplies += df['nreplies'].sum()
# #         print(df['photos'])
# question 3
print(tweetsize/ tweets)
# question 4
print(tweetsize)
# question 5
print((((nlikes + nretweets + nreplies))/0.05)/5781600)
# question 6
print((((nlikes + nretweets + nreplies))/0.05) /5781600 * ((tweetsize/ tweets)))
